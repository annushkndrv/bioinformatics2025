# %% [markdown]
# получила html отчеты fastqc командой:

# %% [markdown]
# ![image.png](attachment:4eb99ae9-ae26-4941-8838-1a5c87586f19.png)

# %% [markdown]
# что видим плохого:
# 1) в обоих файлах качество прочтений (Per base sequence quality)падает к концу,во втором так вообще в "красной золе" (ниже Q20)
# 2)в первом файле распределение Per sequence GC content выше теоретического, много GC фрагментов
# 2) во втором файле наблюдается смещение Per base sequence content (особенно для гуанина)
# 4) в обоих файлах растет illumina universal adapter, так что нам точно нужно что-то делать с нашими файлами

# %% [markdown]
# после тримминга:

# %% [markdown]
# 1) в обоих файлах выросло Per base sequence quality, первый перешел в зеленую зону, второй в желтую из красной
# 2) Per sequence GC content в первом файле не стал лучше, но в целом это может быть особенностью последовательности
# 3) Per base sequence content не перешел в зелёную зону, но визуально линия для гуанина выровнялась, возможно стоит ещё немного подрезать по концам наши последовательности
# 4) Adapter content для обоих файлов стал лучше - теперь в зелёной зоне, ура!

# %% [markdown]
# ![image.png](attachment:49d718bb-24ea-4c75-a036-b067b165bced.png)
